# %%
import matplotlib.pyplot as plt

z=[10**(-10), 10**(-8),10**(-7),10**(-6),10**(-5),10**(-4),10**(-3),10**(-2)]

# %%
delta2=delta=8/255
n=500
aug=10

error=[0.145, 0.145, 0.145, 0.14552, 0.146, 0.146, 0.1475, 0.17515]
error2=[0.147, 0.147, 0.147, 0.148, 0.1465, 0.1465, 0.1475, 0.1735]
plt.semilogx(z,error,label='Aug-')
plt.semilogx(z,error2,label='NoAug-')
plt.legend()
plt.show()

# %%
delta2=delta=8/255
n=500
aug=10

error=[0.13105000000000003, 0.13085, 0.13115000000000002, 0.13105, 0.13165, 0.1336, 0.13970000000000002, 0.1764]
error2=[0.1305, 0.1345, 0.1325, 0.132, 0.1325, 0.134, 0.1395, 0.175]
plt.semilogx(z,error,label='Aug-')
plt.semilogx(z,error2,label='NoAug-')
plt.legend()
plt.show()

# %%
delta=8/255 
delta2=2*delta

error=[0.13930000000000003, 0.13985, 0.13995000000000002, 0.1396, 0.14065, 0.14045000000000002, 0.1405, 0.16770000000000002]
error2=[0.1415, 0.142, 0.1415, 0.1395, 0.1415, 0.14, 0.14, 0.166]

plt.semilogx(z,error,label='Aug-')
plt.semilogx(z,error2,label='NoAug-')
plt.legend()
plt.show()

# %%
delta=8/255 
delta2=2*delta

error=[0.1383, 0.139, 0.13905, 0.13845000000000002, 0.13930000000000003, 0.14030000000000004, 0.14625, 0.1861]
error2=[0.137, 0.14, 0.1385, 0.1395, 0.1395, 0.1395, 0.1465, 0.187]
plt.semilogx(z,error,label='Aug-')
plt.semilogx(z,error2,label='NoAug-')
plt.legend()
plt.show()

# %%
delta=8/255 #noise level
delta2=4*delta

error=[0.1401, 0.1407, 0.1419, 0.1407, 0.14150000000000001, 0.14059999999999997, 0.14354999999999996, 0.18535]
error2=[0.1415, 0.141, 0.142, 0.145, 0.144, 0.1385, 0.142, 0.183]
plt.semilogx(z,error,label='Aug-')
plt.semilogx(z,error2,label='NoAug-')
plt.legend()
plt.show()

# %%
delta=8/255 #noise level
delta2=8*delta
error=[0.13755, 0.1365, 0.1366, 0.1375, 0.13820000000000002, 0.13685000000000003, 0.135, 0.1695]
error2=[0.1435, 0.1375, 0.14, 0.137, 0.136, 0.138, 0.138, 0.1685]
plt.semilogx(z,error,label='Aug-')
plt.semilogx(z,error2,label='NoAug-')
plt.legend()
plt.show()

# %%
delta=16/255 #noise level
delta2=1/2*delta
error=[0.12585, 0.12635000000000002, 0.12605, 0.1258, 0.12595, 0.12764999999999999, 0.13615, 0.17030000000000003]
error2=[0.128, 0.1265, 0.127, 0.128, 0.128, 0.126, 0.135, 0.1685]
plt.semilogx(z,error,label='Aug-')
plt.semilogx(z,error2,label='NoAug-')
plt.legend()
plt.show()

# %%
delta=8/255 #noise level
delta2=1/2*delta
error=[0.12560000000000002, 0.12564999999999998, 0.12575, 0.1258, 0.1269, 0.1251, 0.13165, 0.179]
error2=[0.127, 0.127, 0.1275, 0.127, 0.1275, 0.1255, 0.1315, 0.177]
plt.semilogx(z,error,label='Aug-')
plt.semilogx(z,error2,label='NoAug-')
plt.legend()
plt.show()

# %%
n=1000 # number of sample
delta=8/255 #noise level
delta2=delta
aug=10
error=[0.12044999999999999, 0.12050000000000001, 0.12075, 0.12035, 0.12144999999999999, 0.12010000000000001, 0.1303, 0.1773]
error2=[0.123, 0.123, 0.1235, 0.1235, 0.1225, 0.1195, 0.1305, 0.1765]
plt.semilogx(z,error,label='Aug-')
plt.semilogx(z,error2,label='NoAug-')
plt.legend()
plt.show()

# %%
n=500 # number of sample
delta=8/255 #noise level
delta2=delta
aug=5
#laplace kernel
error=[0.13755, 0.13815000000000002, 0.13755, 0.13765, 0.1395, 0.151, 0.1992, 0.2541]
error2=[0.1395, 0.141, 0.14, 0.1415, 0.1435, 0.152, 0.1985, 0.253]
plt.semilogx(z,error,label='Aug-')
plt.semilogx(z,error2,label='NoAug-')
plt.legend()
plt.show()
